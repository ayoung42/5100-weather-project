# %% [markdown]
# # Load and explore the data

# %% [markdown]
# ## Import libraries

# %%
# Import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# seaborn is a data visualization library built on matplotlib
import seaborn as sns

# set the plotting style
sns.set_style("whitegrid")

# %% [markdown]
# ## Load the data

# %% [markdown]
# ##### Load the from gitbub

# %%
#df_seattle2= pd.read_csv(
#    'https://raw.githubusercontent.com/brian-fischer/DATA-5100/refs/heads/main/weather/seattle_rain.csv'
#)
#df_seattle2

# %% [markdown]
# ##### Load the Seattle data set

# %%
df1 = pd.read_csv('seattle_rain.csv')
seattle = df1.copy()

# %% [markdown]
# ##### Load the St. Louis data set

# %%
df2 = pd.read_csv('stl_rain.csv')
stl= df2.copy()

# %% [markdown]
# ## Explore the contents of the data sets

# %% [markdown]
# ##### Start by looking at the head of each data frame.
#
# This will let us see the names of the columns and a few example values for each column.

# %%
seattle.head()
# Out:
#        STATION                    NAME    DATE  DAPR  MDPR  PRCP  SNOW  SNWD  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/1/18   NaN   NaN  0.00   NaN   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/2/18   NaN   NaN  0.00   NaN   NaN
# 2  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/3/18   NaN   NaN  0.00   NaN   NaN
# 3  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/4/18   NaN   NaN  0.00   NaN   NaN
# 4  US1WAKG0225  SEATTLE 2.1 ESE, WA US  1/5/18   NaN   NaN  0.25   NaN   NaN
#
#    WESD  WESF
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN

# %%
stl.head()
# Out:
#        STATION                       NAME        DATE  DAPR  MDPR  PRCP  SNOW  \
# 0  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-01   NaN   NaN  0.00   0.0
# 1  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-03   NaN   NaN  0.35   NaN
# 2  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-04   NaN   NaN  0.03   NaN
# 3  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-05   NaN   NaN  0.04   1.2
# 4  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-06   NaN   NaN  0.00   0.0
#
#    SNWD
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   1.0

# %% [markdown]
# ##### Examine more rows

# %%
seattle.head(20)
# Out:
#         STATION                    NAME     DATE  DAPR  MDPR  PRCP  SNOW  \
# 0   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/1/18   NaN   NaN  0.00   NaN
# 1   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/2/18   NaN   NaN  0.00   NaN
# 2   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/3/18   NaN   NaN  0.00   NaN
# 3   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/4/18   NaN   NaN  0.00   NaN
# 4   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/5/18   NaN   NaN  0.25   NaN
# 5   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/6/18   NaN   NaN  0.57   NaN
# 6   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/7/18   NaN   NaN  0.23   NaN
# 7   US1WAKG0225  SEATTLE 2.1 ESE, WA US   1/8/18   NaN   NaN  0.41   NaN
# 8   US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/12/18   NaN   NaN  0.00   NaN
# 9   US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/13/18   NaN   NaN  0.00   NaN
# 10  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/14/18   NaN   NaN  0.20   NaN
# 11  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/15/18   NaN   NaN  0.02   NaN
# 12  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/16/18   NaN   NaN  0.00   NaN
# 13  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/17/18   NaN   NaN  0.00   NaN
# 14  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/18/18   NaN   NaN  0.00   NaN
# 15  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/19/18   NaN   NaN  0.00   NaN
# 16  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/20/18   NaN   NaN  0.00   NaN
# 17  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/21/18   NaN   NaN  0.00   NaN
# 18  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/22/18   NaN   NaN  0.25   NaN
# 19  US1WAKG0225  SEATTLE 2.1 ESE, WA US  3/23/18   NaN   NaN  0.29   NaN
#
#     SNWD  WESD  WESF
# 0    NaN   NaN   NaN
# 1    NaN   NaN   NaN
# 2    NaN   NaN   NaN
# 3    NaN   NaN   NaN
# 4    NaN   NaN   NaN
# 5    NaN   NaN   NaN
# 6    NaN   NaN   NaN
# 7    NaN   NaN   NaN
# 8    NaN   NaN   NaN
# 9    NaN   NaN   NaN
# 10   NaN   NaN   NaN
# 11   NaN   NaN   NaN
# 12   NaN   NaN   NaN
# 13   NaN   NaN   NaN
# 14   NaN   NaN   NaN
# 15   NaN   NaN   NaN
# 16   NaN   NaN   NaN
# 17   NaN   NaN   NaN
# 18   NaN   NaN   NaN
# 19   NaN   NaN   NaN

# %% [markdown]
# ##### St. Louis data set

# %%
stl.head(20)
# Out:
#         STATION                       NAME        DATE  DAPR  MDPR  PRCP  \
# 0   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-01   NaN   NaN  0.00
# 1   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-03   NaN   NaN  0.35
# 2   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-04   NaN   NaN  0.03
# 3   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-05   NaN   NaN  0.04
# 4   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-06   NaN   NaN  0.00
# 5   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-10   NaN   NaN  0.00
# 6   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-11   NaN   NaN  0.00
# 7   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-12   NaN   NaN  0.00
# 8   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-13   NaN   NaN  0.00
# 9   US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-14   NaN   NaN  0.51
# 10  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-15   NaN   NaN  0.11
# 11  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-16   NaN   NaN  0.17
# 12  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-17   NaN   NaN  0.06
# 13  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-18   NaN   NaN  0.00
# 14  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-19   NaN   NaN  0.02
# 15  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-20   NaN   NaN  0.13
# 16  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-21   NaN   NaN  0.00
# 17  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-23   NaN   NaN  0.00
# 18  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-24   NaN   NaN  0.00
# 19  US1MOSS0027  ST. CHARLES 2.3 NE, MO US  2017-01-25   NaN   NaN  0.00
#
#     SNOW  SNWD
# 0    0.0   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    1.2   NaN
# 4    0.0   1.0
# 5    0.0   NaN
# 6    0.0   NaN
# 7    NaN   NaN
# 8    0.0   NaN
# 9    0.1   NaN
# 10   NaN   NaN
# 11   NaN   NaN
# 12   NaN   NaN
# 13   0.0   NaN
# 14   NaN   NaN
# 15   NaN   NaN
# 16   0.0   NaN
# 17   0.0   NaN
# 18   0.0   NaN
# 19   0.0   NaN

# %% [markdown]
# ##### Are the columns are the same?

# %%
seattle.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'DAPR', 'MDPR', 'PRCP', 'SNOW', 'SNWD',
#        'WESD', 'WESF'],
#       dtype='object')

# %%
stl.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'DAPR', 'MDPR', 'PRCP', 'SNOW', 'SNWD'], dtype='object')

# %% [markdown]
# ##### Use the `info` method to check the data types, size of the data frame, and numbers of missing values.

# %%
seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1658 entries, 0 to 1657
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1658 non-null   object
#  1   NAME     1658 non-null   object
#  2   DATE     1658 non-null   object
#  3   DAPR     23 non-null     float64
#  4   MDPR     23 non-null     float64
#  5   PRCP     1636 non-null   float64
#  6   SNOW     353 non-null    float64
#  7   SNWD     66 non-null     float64
#  8   WESD     15 non-null     float64
#  9   WESF     28 non-null     float64
# dtypes: float64(7), object(3)
# memory usage: 129.7+ KB

# %% [markdown]
# ##### St. Louis data set

# %%
stl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54574 entries, 0 to 54573
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  54574 non-null  object
#  1   NAME     54574 non-null  object
#  2   DATE     54574 non-null  object
#  3   DAPR     1166 non-null   float64
#  4   MDPR     1163 non-null   float64
#  5   PRCP     53143 non-null  float64
#  6   SNOW     33167 non-null  float64
#  7   SNWD     12835 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# ##### We can also compare data frame sizes using the shape attribute

# %%
seattle.shape
# Out:
# (1658, 10)

# %%
stl.shape
# Out:
# (54574, 8)

# %% [markdown]
# ## Why might the St. Louis data set be larger?

# %% [markdown]
# <pre>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </pre>

# %% [markdown]
# #### Examine the `STATION` column

# %% [markdown]
# ##### How many unique stations are present?

# %%
unique_stations = seattle['STATION'].unique()
print("\nUnique_stations in 'STATION' column:")
print(unique_stations)
# Out:
# Unique_stations in 'STATION' column:
# ['US1WAKG0225']

# %%
unique_stations_stl = stl['STATION'].unique()
print("\nUnique_stations in 'STATION' column:")
print(unique_stations_stl)
# Out:
# Unique_stations in 'STATION' column:
# ['US1MOSS0027' 'US1MOSL0019' 'US1MOSL0018' 'US1MOSL0039' 'US1MOSLC010'
#  'US1ILSC0009' 'US1MOSL0050' 'US1MOJF0018' 'US1MOSL0070' 'US1MOSL0092'
#  'US1MOSL0079' 'US1MOSL0056' 'US1MOSL0055' 'US1MOSL0077' 'US1ILMD0047'
#  'US1MOSL0054' 'US1MOSL0076' 'US1MOSL0074' 'US1MOSLC007' 'US1MOFSA189'
#  'US1MOSL0027' 'US1MOSL0049' 'US1MOSL0004' 'USC00237397' 'USC00237452'
#  'USC00237398' 'US1ILSC0018' 'US1MOSS0034' 'USW00003960' 'US1MOSL0083'
#  'US1ILMO0006' 'US1MOSL0081' 'US1MOJF0025' 'US1MOSS0051' 'US1ILMD0010'
#  'US1MOSL0024' 'US1MOSL0045' 'US1MOSL0067' 'US1MOSL0020' 'US1ILMD0012'
#  'US1MOSL0063' 'USW00013994' 'US1MOSL0062' 'US1MOSL0084']

# %% [markdown]
# #### Examine the `DATE` column

# %%
seattle['DATE'].head()
# Out:
# 0    1/1/18
# 1    1/2/18
# 2    1/3/18
# 3    1/4/18
# 4    1/5/18
# Name: DATE, dtype: object

# %%
stl['DATE'].head()
# Out:
# 0    2017-01-01
# 1    2017-01-03
# 2    2017-01-04
# 3    2017-01-05
# 4    2017-01-06
# Name: DATE, dtype: object

# %% [markdown]
# ### Be careful to use correct data types

# %% [markdown]
# ### Convert `DATE` to datetime

# %%
from datetime import datetime

# %%
seattle['DATE'] = pd.to_datetime(seattle['DATE'])
seattle['DATE'].tail()
stl['DATE'] = pd.to_datetime(stl['DATE'])

# %% [markdown]
# ### What range of dates are present?

# %%
seattle['DATE'].agg(['min','max'])
# Out:
# min   2018-01-01
# max   2022-12-31
# Name: DATE, dtype: datetime64[ns]

# %%
stl['DATE'].agg(['min', 'max'])
# Out:
# min   2018-01-01
# max   2022-12-31
# Name: DATE, dtype: datetime64[ns]

# %% [markdown]
# ### Are the data suitable for answering the question?

# %% [markdown]
# Plot the daily precipitation data for Seattle.

# %%
plt.figure(figsize= (20,5))

sns.lineplot(data= seattle, x = 'DATE', y = 'PRCP')

plt.xlabel('Date', fontsize= 18)
plt.ylabel('Precipitation (inchers)', fontsize = 18)

plt.tick_params(labelsize = 15)
plt.show()

# %% [markdown]
# ##### Plot the daily precipitation data for St. Louis.

# %%
#plt.figure(figsize= (20,5))

#sns.lineplot(data= stl, x = 'DATE', y = 'PRCP')

#plt.xlabel('Date', fontsize= 18)
#plt.ylabel('Precipitation (inchers)', fontsize = 18)

#plt.tick_params(labelsize = 15)
#plt.show()

# %% [markdown]
# ### Tutorial: Selecting subsets of a DataFrame

# %% [markdown]
# ### Select one column

# %% [markdown]
# Select the column containing precipitation `PRCP`.

# %%
seattle['PRCP'].head()
# Out:
# 0    0.00
# 1    0.00
# 2    0.00
# 3    0.00
# 4    0.25
# Name: PRCP, dtype: float64

# %%
stl['PRCP'].head()
# Out:
# 51540    0.0
# 51541    0.0
# 51542    0.0
# 51543    0.0
# 51544    0.0
# Name: PRCP, dtype: float64

# %% [markdown]
# #### Use dictionary-style indexing

# %% [markdown]
# #### Use explicit array-style indexing with loc

# %% [markdown]
# #### Use implicit array-style indexing with `.iloc`

# %% [markdown]
# What number column, starting with 0, is `PRCP`?

# %%
seattle.head()
# Out:
#        STATION                    NAME       DATE  DAPR  MDPR  PRCP  SNOW  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-01   NaN   NaN  0.00   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-02   NaN   NaN  0.00   NaN
# 2  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-03   NaN   NaN  0.00   NaN
# 3  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-04   NaN   NaN  0.00   NaN
# 4  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-05   NaN   NaN  0.25   NaN
#
#    SNWD  WESD  WESF
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN

# %% [markdown]
# ##### Use implicit array-style indexing with `.iloc`

# %% [markdown]
# ### Select multiple columns

# %% [markdown]
# Select the columns containing `STATION`, `DATE`, and precipitation `PRCP`.

# %%
seattle_col = seattle[["STATION", "DATE", "PRCP"]]
stl_col = stl[["STATION", "DATE", "PRCP"]]

# %% [markdown]
# ##### Use .loc

# %%
seattle_col = seattle.loc(axis=1)['STATION', 'DATE', 'PRCP']
seattle_col = stl.loc(axis=1)['STATION', 'DATE', 'PRCP']

# %% [markdown]
# ##### Use .iloc

# %%
some_seattle1 = seattle.iloc(axis=1)[[0, 2,5]]
some_seattle1.head()
# Out:
#        STATION       DATE  PRCP
# 0  US1WAKG0225 2018-01-01  0.00
# 1  US1WAKG0225 2018-01-02  0.00
# 2  US1WAKG0225 2018-01-03  0.00
# 3  US1WAKG0225 2018-01-04  0.00
# 4  US1WAKG0225 2018-01-05  0.25

# %%
some_stl1 = stl.iloc(axis=1)[[0, 2,5]]
some_stl1.head()
# Out:
#            STATION       DATE  PRCP
# 51540  USW00013994 2018-01-01   0.0
# 51541  USW00013994 2018-01-02   0.0
# 51542  USW00013994 2018-01-03   0.0
# 51543  USW00013994 2018-01-04   0.0
# 51544  USW00013994 2018-01-05   0.0

# %% [markdown]
# #### Select a range of columns

# %% [markdown]
# Select all columns from `STATION` through `PRCP`

# %% [markdown]
# ##### Use .iloc

# %%
some_seattle2= seattle.iloc(axis=1)[:6]
some_seattle2.head()
# Out:
#        STATION                    NAME       DATE  DAPR  MDPR  PRCP
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-01   NaN   NaN  0.00
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-02   NaN   NaN  0.00
# 2  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-03   NaN   NaN  0.00
# 3  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-04   NaN   NaN  0.00
# 4  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-05   NaN   NaN  0.25

# %%
some_stl2= stl.iloc(axis=1)[:6]
some_stl2.head()
# Out:
#            STATION                                           NAME       DATE  \
# 51540  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-01
# 51541  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-02
# 51542  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-03
# 51543  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-04
# 51544  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-05
#
#        DAPR  MDPR  PRCP
# 51540   NaN   NaN   0.0
# 51541   NaN   NaN   0.0
# 51542   NaN   NaN   0.0
# 51543   NaN   NaN   0.0
# 51544   NaN   NaN   0.0

# %% [markdown]
# ### Select the first $n$ rows

# %% [markdown]
# Select the first 3 rows

# %% [markdown]
# Use the `.head()` method

# %% [markdown]
# ##### Use explicit indexing

# %% [markdown]
# ##### Use implicit indexing

# %% [markdown]
# ### Select the last $n$ rows

# %% [markdown]
# Use the `.tail()` method

# %% [markdown]
# ##### Use explicit indexing

# %% [markdown]
# ##### Use implicit indexing

# %% [markdown]
# ### Select rows using logical indexing

# %% [markdown]
# Select the rows where `PRCP` is greater than 0.

# %% [markdown]
# ##### Select the rows where the precipitation is between 0.5 and 0.75 inches.

# %% [markdown]
# ## Select relevant subsets of the data

# %% [markdown]
# We saw that the St. Louis data set contains data prior to 2018.

# %%
stl.head()
# Out:
#            STATION                                           NAME       DATE  \
# 51540  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-01
# 51541  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-02
# 51542  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-03
# 51543  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-04
# 51544  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-05
#
#        DAPR  MDPR  PRCP  SNOW  SNWD
# 51540   NaN   NaN   0.0   0.0   0.0
# 51541   NaN   NaN   0.0   0.0   0.0
# 51542   NaN   NaN   0.0   0.0   0.0
# 51543   NaN   NaN   0.0   0.2   0.0
# 51544   NaN   NaN   0.0   0.0   0.0

# %% [markdown]
# ##### Limit the St. Louis data to 2018 and beyond.

# %%
stl= stl.loc[stl['DATE'] >= '2018-01-01']

# %%
stl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1826 entries, 51540 to 53365
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  1826 non-null   object
#  1   NAME     1826 non-null   object
#  2   DATE     1826 non-null   datetime64[ns]
#  3   DAPR     0 non-null      float64
#  4   MDPR     0 non-null      float64
#  5   PRCP     1826 non-null   float64
#  6   SNOW     1826 non-null   float64
#  7   SNWD     1826 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 128.4+ KB

# %%
stl['NAME'].unique()
# Out:
# array(['ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US'], dtype=object)

# %% [markdown]
# ##### The St. Louis data set has values for many weather stations, while the Seattle data set has only one weather station.
#
# We will focus on the data from the airport in St. Louis.

# %%
stl= stl.loc[stl['NAME']== 'ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US']

# %% [markdown]
# ## Join data frames keeping `DATE` and `PRCP` columns

# %%
seattle.head(2)
# Out:
#        STATION                    NAME       DATE  DAPR  MDPR  PRCP  SNOW  \
# 0  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-01   NaN   NaN   0.0   NaN
# 1  US1WAKG0225  SEATTLE 2.1 ESE, WA US 2018-01-02   NaN   NaN   0.0   NaN
#
#    SNWD  WESD  WESF
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN

# %%
stl.head(2)
# Out:
#            STATION                                           NAME       DATE  \
# 51540  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-01
# 51541  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US 2018-01-02
#
#        DAPR  MDPR  PRCP  SNOW  SNWD
# 51540   NaN   NaN   0.0   0.0   0.0
# 51541   NaN   NaN   0.0   0.0   0.0

# %% [markdown]
# **What type of join should we do?**

# %% [markdown]
# ##### outer join, keeps the data where they are not the same

# %% [markdown]
# ##### Use a join to keep all dates present

# %%
df= stl[['DATE','PRCP']].merge(seattle[['DATE','PRCP']], on= 'DATE', how ='outer')

# %%
df
# Out:
#            DATE  PRCP_x  PRCP_y
# 0    2018-01-01    0.00    0.00
# 1    2018-01-02    0.00    0.00
# 2    2018-01-03    0.00    0.00
# 3    2018-01-04    0.00    0.00
# 4    2018-01-05    0.00    0.25
# ...         ...     ...     ...
# 1821 2022-12-27    0.00    0.78
# 1822 2022-12-28    0.00    0.40
# 1823 2022-12-29    0.00    0.03
# 1824 2022-12-30    0.31    0.62
# 1825 2022-12-31    0.00    0.17
#
# [1826 rows x 3 columns]

# %% [markdown]
# Each DataFrame had a column named `PRCP`, so the default is to add suffixes _x and _y to differentiate the columns. Normally, I would rename the columns at this point to something more informative. However, I know that I want to convert the DataFrame to a tidy format and I will modify the names later.

# %% [markdown]
# ### Create a tidy data frame with columns for city and precipitation

# %% [markdown]
# How did this change the DataFrame?

# %%
#df3= pd.melt(df, id_vars='DATE', var_name= 'city', value_name='precipitation')
df= pd.melt(df, id_vars=['DATE'], var_name='city', value_name='precipitation')
df.head()
# Out:
#         DATE    city  precipitation
# 0 2018-01-01  PRCP_x            0.0
# 1 2018-01-02  PRCP_x            0.0
# 2 2018-01-03  PRCP_x            0.0
# 3 2018-01-04  PRCP_x            0.0
# 4 2018-01-05  PRCP_x            0.0

# %% [markdown]
# ### Rename columns or values to follow best practices

# %% [markdown]
# Rename the city values 'STL' and 'SEA'

# %%
df.loc[df['city'] == 'PRCP_x', 'city'] = 'STL'
df.loc[df['city'] == 'PRCP_y', 'city'] = 'SEA'

# %%
df.tail()
# Out:
#            DATE city  precipitation
# 3647 2022-12-27  SEA           0.78
# 3648 2022-12-28  SEA           0.40
# 3649 2022-12-29  SEA           0.03
# 3650 2022-12-30  SEA           0.62
# 3651 2022-12-31  SEA           0.17

# %% [markdown]
# ##### Rename the columns to be lowercase using `df.rename()`

# %%
df.rename(str.lower, axis='columns')
# Out:
#            date city  precipitation
# 0    2018-01-01  STL           0.00
# 1    2018-01-02  STL           0.00
# 2    2018-01-03  STL           0.00
# 3    2018-01-04  STL           0.00
# 4    2018-01-05  STL           0.00
# ...         ...  ...            ...
# 3647 2022-12-27  SEA           0.78
# 3648 2022-12-28  SEA           0.40
# 3649 2022-12-29  SEA           0.03
# 3650 2022-12-30  SEA           0.62
# 3651 2022-12-31  SEA           0.17
#
# [3652 rows x 3 columns]

# %% [markdown]
# ## Identify and fill in missing values

# %% [markdown]
# Data can be missing in multiple manners:
# 1. Values are `NaN` in the data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           3652 non-null   datetime64[ns]
#  1   city           3652 non-null   object
#  2   precipitation  3462 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 85.7+ KB

# %% [markdown]
# 2.  Values are not included in the data set.

# %% [markdown]
# ### Count the non-null or null values

# %% [markdown]
# Determine the number of non-null values in each column.

# %%
df.notna().sum()
# Out:
# DATE             3652
# city             3652
# precipitation    3462
# dtype: int64

# %% [markdown]
# ##### Determine the number of null values in each column.

# %%
df.isna().sum()
# Out:
# DATE               0
# city               0
# precipitation    190
# dtype: int64

# %% [markdown]
# ##### Determine the number of null precipitation values for Seattle and St. Louis.

# %%
df.loc[df['city']== 'SEA', 'precipitation'].isna().sum()
# Out:
# np.int64(190)

# %%
df.loc[df['city']== 'STL', 'precipitation'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### The St. Louis data set does not have any `NaN` values of `precipitation`. Are any dates omitted?
#
# **How many data points should we have from 2018 to 2022?**

# %% [markdown]
# 5*365+1

# %% [markdown]
# ### Impute missing values

# %% [markdown]
# We will replace missing values with the mean across years of values on that day.
#
#
# **Design an algorithm for replacing missing values with the mean across years of values on that day.**

# %% [markdown]
# #### take the average on similar days and replace them

# %% [markdown]
# ## Export the clean .csv file

# %%
df.to_csv('clean_seattle_stlouis_weather.csv', encoding='utf-8-sig', index=False)
